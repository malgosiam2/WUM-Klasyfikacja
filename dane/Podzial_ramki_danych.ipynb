# %% [markdown]
# # Podział ramki danych
# ### Stellar Classification Dataset - SDSS17
# https://www.kaggle.com/datasets/fedesoriano/stellar-classification-dataset-sdss17

# %% [markdown]
# <img src="data:image/png;base64,..." alt="" />

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import sklearn 
from sklearn.model_selection import train_test_split
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
np.random.seed = 42

# %%
df = pd.read_csv('star_classification.csv')
df.head()
# Out:
#          obj_ID       alpha      delta         u         g         r  \
# 0  1.237661e+18  135.689107  32.494632  23.87882  22.27530  20.39501
# 1  1.237665e+18  144.826101  31.274185  24.77759  22.83188  22.58444
# 2  1.237661e+18  142.188790  35.582444  25.26307  22.66389  20.60976
# 3  1.237663e+18  338.741038  -0.402828  22.13682  23.77656  21.61162
# 4  1.237680e+18  345.282593  21.183866  19.43718  17.58028  16.49747
#
#           i         z  run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID  \
# 0  19.16573  18.79371    3606       301        2        79  6.543777e+18
# 1  21.16812  21.61427    4518       301        5       119  1.176014e+19
# 2  19.34857  18.94827    3606       301        2       120  5.152200e+18
# 3  20.50454  19.25010    4192       301        3       214  1.030107e+19
# 4  15.97711  15.54461    8102       301        3       137  6.891865e+18
#
#     class  redshift  plate    MJD  fiber_ID
# 0  GALAXY  0.634794   5812  56354       171
# ...

# %%
development_unit_tmp_df, test_sample_df = train_test_split(df, test_size=0.3, random_state=42)

# %%
training_sample_df, validation_sample_df = train_test_split(development_unit_tmp_df, test_size=0.3, random_state=42)

# %%
training_sample_df.to_csv("training_sample_team4.csv", index=False)
training_sample_df.head()
# Out:
#              obj_ID       alpha      delta         u         g         r  \
# 30678  1.237651e+18  147.392648   0.145509  23.62785  21.78850  21.73961
# 15253  1.237665e+18  157.156740  35.327317  18.60880  17.52187  17.12905
# 80529  1.237667e+18   94.688025  63.535297  18.16716  16.51485  15.75641
# 86244  1.237655e+18  214.420238  -1.506597  19.83027  18.47293  17.82672
# 64078  1.237668e+18  204.749167  17.703206  19.33024  18.16558  17.74244
#
#               i         z  run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID  \
# 30678  21.88235  21.43752    1239       301        4       181  4.308885e+18
# 15253  16.95103  16.89711    4518       301        6       192  2.204664e+18
# 80529  15.35805  15.23041    5060       301        1       100  2.588464e+18
# 86244  17.48600  17.26200    2334       301        5       124  1.032563e+18
# 64078  17.48129  17.32534    5314       301        1       181  2.935343e+18
#
#         class  redshift  plate    MJD  fiber_ID
# ...

# %%
validation_sample_df.to_csv("validation_sample_team4.csv", index=False)
validation_sample_df.head()
# Out:
#              obj_ID       alpha      delta         u         g         r  \
# 27524  1.237679e+18  359.289119  17.897029  23.61143  21.33427  21.08527
# 56435  1.237679e+18   25.580975  21.533531  22.45473  21.12307  21.23810
# 91394  1.237680e+18  335.883610  20.300184  21.22187  21.05593  20.74334
# 40013  1.237663e+18  332.460054   0.162270  23.74808  21.87556  20.30788
# 43671  1.237661e+18  128.028315  28.713084  23.76493  22.22703  20.48065
#
#               i         z  run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID  \
# 27524  21.09826  20.72268    7912       301        5       152  6.988660e+18
# 56435  20.72731  20.69970    7917       301        4       263  8.155117e+18
# 91394  20.46805  20.78835    8102       301        4        78  8.532336e+18
# 40013  18.87652  18.14865    4192       301        4       172  4.201122e+17
# 43671  19.52488  19.10254    3560       301        4       137  5.014898e+18
#
#         class  redshift  plate    MJD  fiber_ID
# ...

# %%
test_sample_df.to_csv("test_sample_team4.csv", index=False)
test_sample_df.head()
